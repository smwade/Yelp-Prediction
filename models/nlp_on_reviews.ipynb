# %% [markdown]
# # NONE OF THIS WORKS...

# %%
import pandas as pd
import nltk
from sklearn.naive_bayes import GaussianNB
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
from nltk import tokenize

# %%
reviews = pd.read_csv('../data/az_review.csv')

# %%
text = reviews['text'][6]

# %%
import nltk
import re
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords


def removeStopPunc(text):
    tokenizer = RegexpTokenizer(r'\w+')
    words = tokenizer.tokenize(text.lower())
    stop = stopwords.words('english')
    newwords = [w for w in words if w not in stop]
    return newwords


def posTag(text):
    text = nltk.sent_tokenize(text)
    text = [nltk.word_tokenize(sent) for sent in text]
    text = [nltk.pos_tag(sent) for sent in text]
    return text


def posExtract(text, pattern):
    words = [word for sent in text for (word,tag) in sent if re.match(pattern, tag)]
    return words

# %%
text = "This place is the worst!!!"

# %%
sid = SentimentIntensityAnalyzer()

# %%
for review in reviews['text'][:50]:
    ss = sid.polarity_scores(review)
    compound_rate = ss['compound']
    pos_rate = ss['pos']
    neu_rate = ss['neu'] 
    neg_rate = ss['neg']
    print"-" * 30
    print review
    print "Pos Rate: %f" % pos_rate
    print "Neg Rate: %f" % neg_rate
    print "Nue Rate: %f" % neu_rate
# Out:
# ------------------------------
# The scam of the century! I'm still horrified! Please do not believe the shop assistants in this store!
# We bought a sleep number mattress in this store in January. No complaints about the product but they deliberately lie to us in all the information they gave us!
# We were going to move back to Europe so we specifically ask about two things:
# The warranty- we were told sure no problem! the warranty will be valid, just need to contact customer service. I quote also "Our beds go often abroad, just yesterday I sent a bed to Puerto Rico"
# The pump, is it dual voltage so it can be used in Europe?- " yes it is dual voltage no problems there"
# Well, we are in Europe now after paying 3000$ for this bed. We plugged the pump and sure, after working for 5 min it stopped, burnt smell... No, the pump is not dual voltage!- first disgraceful lie
# ...
